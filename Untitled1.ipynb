# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreyStY/TG/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Примеры использования Markdown
# Нужно сделать:
# 1. Список.
# 2. Рисунок.
# 3. Таблицу.
# 4. Ссылку.
# ![Sign_001.jpg](data:image/jpeg;base64,...)
#
# First column name  | Second column name
# -------------------|------------------
# Row 1, Col 1       | Row 1, Col 2
# Row 2, Col 1       | Row 2, Col 2
#
# [Ссылка на руководство по Markdown](https://gist.github.com/Jekins/2bf2d0638163f1294637)
